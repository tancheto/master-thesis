# %%
import os
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

import sys
sys.path.append(os.path.abspath('..'))
from util import train_model_on_datasets

# %% [markdown]
# Histogram-based Gradient Boosting Classification Tree

# %%
# Create your model here
clf = HistGradientBoostingClassifier()

# Fit the model to the training data
train_model_on_datasets(clf)

# %% [markdown]
# XGBoost

# %%
xgb = XGBClassifier(
    subsample=0.75,
    min_child_weight=10,
    max_depth=6,
    learning_rate=0.01,
    gamma=1,
    colsample_bytree=1.0,
    booster='gbtree',
    objective='binary:hinge',
    silent=True,
    nthread=-1
)

train_model_on_datasets(xgb)
# Out:
# no resampling, w/o sensitive attribute
# [22:03:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.111227
# Caucasian             0.113056
# Other                 0.102564
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.029632712453962498
# The Disparate impact ratio on the training data: 0.9491723328270318
#
# ===After training the model===
# The accuracy score for the testing data: 0.8797228909743036
# The precision score for the testing data: 0.31049250535331907
# The recall score for the testing data: 0.06384852487890796
# The F1 score for the testing data: 0.10591672753834916
# The F2 score for the testing data: 0.07590828185530311
# The specificity score for the testing data: 0.9821922353721934
# The balanced accuracy score for the testing data: 0.5230203801255506
# The G mean score for the testing data: 0.25042269341262124
# [[17760   322]
#  [ 2126   145]]
#                 selection_rate
# race
# AfricanAmerican       0.025707
# Caucasian             0.023144
# Other                 0.015682
# Unknown               0.004706
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.021001058521094816
# The Equalized odds difference score on the trained model: 0.07692307692307693
# The Equal opportunity difference score on the trained model: 0.06384852487890796
# The Disparate impact ratio on the trained model: 0.9659505116287289
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC2237EB0>
#
# no resampling, with sensitive attribute
# [22:03:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.111227
# Caucasian             0.113056
# Other                 0.102564
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.029632712453962498
# The Disparate impact ratio on the training data: 0.9491723328270318
#
# ===After training the model===
# The accuracy score for the testing data: 0.8800176878101509
# The precision score for the testing data: 0.3137254901960784
# The recall score for the testing data: 0.06340819022457067
# The F1 score for the testing data: 0.10549450549450548
# The F2 score for the testing data: 0.07544797233574348
# The specificity score for the testing data: 0.9825793606901891
# The balanced accuracy score for the testing data: 0.5229937754573799
# The G mean score for the testing data: 0.24960684889117238
# [[17767   315]
#  [ 2127   144]]
#                 selection_rate
# race
# AfricanAmerican        0.02545
# Caucasian             0.022684
# Other                 0.015682
# Unknown               0.004706
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.020743989112354456
# The Equalized odds difference score on the trained model: 0.07692307692307693
# The Equal opportunity difference score on the trained model: 0.06340819022457067
# The Disparate impact ratio on the trained model: 0.9769795117993102
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC2237130>
#
# target-resample, w/o sensitive attribute
# [22:03:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican       0.490783
# Caucasian             0.506065
# Other                 0.481119
# Unknown               0.403141
# The Demographic parity difference score on the training data: 0.10292347738199109
# The Disparate impact ratio on the training data: 0.9523355422167098
#
# ===After training the model===
# The accuracy score for the testing data: 0.11467596914459785
# The precision score for the testing data: 0.111812265825281
# The recall score for the testing data: 0.9986789960369881
# The F1 score for the testing data: 0.20110840168477057
# The F2 score for the testing data: 0.38613456823753745
# The specificity score for the testing data: 0.0036500387125317996
# The balanced accuracy score for the testing data: 0.50116451737476
# The G mean score for the testing data: 0.06037563247641714
# [[   66 18016]
#  [    3  2268]]
#                 selection_rate
# race
# AfricanAmerican       0.995373
# Caucasian             0.997501
# Other                 0.986731
# Unknown               0.995294
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.010770478180932241
# The Equalized odds difference score on the trained model: 0.02941176470588236
# The Equal opportunity difference score on the trained model: 0.9986789960369881
# The Disparate impact ratio on the trained model: 0.996463245389291
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC535F010>
#
# target-resample, with sensitive attribute
# [22:03:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican       0.490783
# Caucasian             0.506065
# Other                 0.481119
# Unknown               0.403141
# The Demographic parity difference score on the training data: 0.10292347738199109
# The Disparate impact ratio on the training data: 0.9523355422167098
#
# ===After training the model===
# The accuracy score for the testing data: 0.11467596914459785
# The precision score for the testing data: 0.111812265825281
# The recall score for the testing data: 0.9986789960369881
# The F1 score for the testing data: 0.20110840168477057
# The F2 score for the testing data: 0.38613456823753745
# The specificity score for the testing data: 0.0036500387125317996
# The balanced accuracy score for the testing data: 0.50116451737476
# The G mean score for the testing data: 0.06037563247641714
# [[   66 18016]
#  [    3  2268]]
#                 selection_rate
# race
# AfricanAmerican       0.995373
# Caucasian             0.997501
# Other                 0.986731
# Unknown               0.995294
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.010770478180932241
# The Equalized odds difference score on the trained model: 0.02941176470588236
# The Equal opportunity difference score on the trained model: 0.9986789960369881
# The Disparate impact ratio on the trained model: 0.996463245389291
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC540FC10>
#
# sensitive-resample, w/o sensitive attribute
# [22:03:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.114843
# Caucasian             0.106717
# Other                 0.096425
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.0314192849404117
# The Disparate impact ratio on the training data: 0.9204737732656514
#
# ===After training the model===
# The accuracy score for the testing data: 0.8691593376897755
# The precision score for the testing data: 0.2688679245283019
# The recall score for the testing data: 0.10039630118890357
# The F1 score for the testing data: 0.1462007053542802
# The F2 score for the testing data: 0.11478050745066454
# The specificity score for the testing data: 0.9657117575489437
# The balanced accuracy score for the testing data: 0.5330540293689237
# The G mean score for the testing data: 0.3113741936521862
# [[17462   620]
#  [ 2043   228]]
#                 selection_rate
# race
# AfricanAmerican       0.053213
# Caucasian             0.039779
# Other                 0.036188
# Unknown               0.014118
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.039095720550430965
# The Equalized odds difference score on the trained model: 0.1130820399113082
# The Equal opportunity difference score on the trained model: 0.10039630118890357
# The Disparate impact ratio on the trained model: 1.187546431371541
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC540FBE0>
#
# sensitive-resample, with sensitive attribute
# [22:03:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.114843
# Caucasian             0.106717
# Other                 0.096425
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.0314192849404117
# The Disparate impact ratio on the training data: 0.9204737732656514
#
# ===After training the model===
# The accuracy score for the testing data: 0.8693067361076992
# The precision score for the testing data: 0.26817640047675806
# The recall score for the testing data: 0.09907529722589167
# The F1 score for the testing data: 0.14469453376205785
# The F2 score for the testing data: 0.11337297188350295
# The specificity score for the testing data: 0.966043579250083
# The balanced accuracy score for the testing data: 0.5325594382379873
# The G mean score for the testing data: 0.3093720329108082
# [[17468   614]
#  [ 2046   225]]
#                 selection_rate
# race
# AfricanAmerican        0.05347
# Caucasian             0.039187
# Other                 0.034982
# Unknown               0.014118
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.039352789959171325
# The Equalized odds difference score on the trained model: 0.1130820399113082
# The Equal opportunity difference score on the trained model: 0.09907529722589167
# The Disparate impact ratio on the trained model: 1.205479179496279
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC546B2B0>
#
# multivariate-resample, w/o sensitive attribute
# [22:03:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican            0.5
# Caucasian                  0.5
# Other                      0.5
# Unknown                    0.5
# The Demographic parity difference score on the training data: 0.0
# The Disparate impact ratio on the training data: 1.0
#
# ===After training the model===
# The accuracy score for the testing data: 0.13034933425047904
# The precision score for the testing data: 0.11301730624529721
# The recall score for the testing data: 0.9920739762219286
# The F1 score for the testing data: 0.20291813023507158
# The F2 score for the testing data: 0.38819394190013445
# The specificity score for the testing data: 0.022121446742616967
# The balanced accuracy score for the testing data: 0.5070977114822728
# The G mean score for the testing data: 0.14814220070503087
# [[  400 17682]
#  [   18  2253]]
#                 selection_rate
# race
# AfricanAmerican       0.983548
# Caucasian             0.979683
# Other                 0.961399
# Unknown               0.969412
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.02214828160418758
# The Equalized odds difference score on the trained model: 0.022759880005217226
# The Equal opportunity difference score on the trained model: 0.9920739762219286
# The Disparate impact ratio on the trained model: 0.9991090812779859
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC54C8670>
#
# multivariate-resample, with sensitive attribute
# [22:03:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "silent" } are not used.
#
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican            0.5
# Caucasian                  0.5
# Other                      0.5
# Unknown                    0.5
# The Demographic parity difference score on the training data: 0.0
# The Disparate impact ratio on the training data: 1.0
#
# ===After training the model===
# The accuracy score for the testing data: 0.12956320935488624
# The precision score for the testing data: 0.11292667034233873
# The recall score for the testing data: 0.9920739762219286
# The F1 score for the testing data: 0.2027720277202772
# The F2 score for the testing data: 0.3879800241088342
# The specificity score for the testing data: 0.02123658887291229
# The balanced accuracy score for the testing data: 0.5066552825474204
# The G mean score for the testing data: 0.14514912044012
# [[  384 17698]
#  [   18  2253]]
#                 selection_rate
# race
# AfricanAmerican       0.986889
# Caucasian              0.97988
# Other                 0.961399
# Unknown               0.969412
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.025490183917812215
# The Equalized odds difference score on the trained model: 0.025989191884892016
# The Equal opportunity difference score on the trained model: 0.9920739762219286
# The Disparate impact ratio on the trained model: 1.0014870658146109
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC54EEC20>

# %% [markdown]
# Random forest

# %%
random_forest = RandomForestClassifier()
train_model_on_datasets(random_forest)
# Out:
# no resampling, w/o sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.111227
# Caucasian             0.113056
# Other                 0.102564
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.029632712453962498
# The Disparate impact ratio on the training data: 0.9491723328270318
#
# ===After training the model===
# The accuracy score for the testing data: 0.8882719992138751
# The precision score for the testing data: 0.42857142857142855
# The recall score for the testing data: 0.003963011889035667
# The F1 score for the testing data: 0.007853403141361256
# The F2 score for the testing data: 0.004942339373970346
# The specificity score for the testing data: 0.9993363565977215
# The balanced accuracy score for the testing data: 0.5016496842433785
# The G mean score for the testing data: 0.06293156491254892
# [[18070    12]
#  [ 2262     9]]
#                 selection_rate
# race
# AfricanAmerican       0.001799
# Caucasian             0.000855
# Other                 0.001206
# Unknown                    0.0
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.0017994858611825194
# The Equalized odds difference score on the trained model: 0.01282051282051282
# The Equal opportunity difference score on the trained model: 0.003963011889035667
# The Disparate impact ratio on the trained model: 1.819476013877258
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC28368F0>
#
# no resampling, with sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.111227
# Caucasian             0.113056
# Other                 0.102564
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.029632712453962498
# The Disparate impact ratio on the training data: 0.9491723328270318
#
# ===After training the model===
# The accuracy score for the testing data: 0.8883702648258242
# The precision score for the testing data: 0.48148148148148145
# The recall score for the testing data: 0.005724350506384853
# The F1 score for the testing data: 0.011314186248912098
# The F2 score for the testing data: 0.007134233344309077
# The specificity score for the testing data: 0.9992257493640084
# The balanced accuracy score for the testing data: 0.5024750499351966
# The G mean score for the testing data: 0.07563014230030676
# [[18068    14]
#  [ 2258    13]]
#                 selection_rate
# race
# AfricanAmerican       0.001028
# Caucasian             0.001381
# Other                 0.002413
# Unknown                    0.0
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# The Demographic parity difference score on the trained model: 0.0024125452352231603
# The Equalized odds difference score on the trained model: 0.02564102564102564
# The Equal opportunity difference score on the trained model: 0.005724350506384853
# The Disparate impact ratio on the trained model: 0.8447567207287271
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC27F85E0>
#
# target-resample, w/o sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican       0.490783
# Caucasian             0.506065
# Other                 0.481119
# Unknown               0.403141
# The Demographic parity difference score on the training data: 0.10292347738199109
# The Disparate impact ratio on the training data: 0.9523355422167098
#
# ===After training the model===
# The accuracy score for the testing data: 0.5996658969193731
# The precision score for the testing data: 0.15627558778804537
# The recall score for the testing data: 0.5882870981946279
# The F1 score for the testing data: 0.24695009242144175
# The F2 score for the testing data: 0.37883513866046614
# The specificity score for the testing data: 0.6010950116137596
# The balanced accuracy score for the testing data: 0.5946910549041937
# The G mean score for the testing data: 0.5946565732601673
# [[10869  7213]
#  [  935  1336]]
#                 selection_rate
# race
# AfricanAmerican       0.429049
# Caucasian             0.425603
# Other                 0.319662
# Unknown               0.334118
# The Demographic parity difference score on the trained model: 0.10938659952059193
# The Equalized odds difference score on the trained model: 0.20464327637928792
# The Equal opportunity difference score on the trained model: 0.5882870981946279
# The Disparate impact ratio on the trained model: 0.9482469230364483
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC27E7940>
#
# target-resample, with sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican       0.490783
# Caucasian             0.506065
# Other                 0.481119
# Unknown               0.403141
# The Demographic parity difference score on the training data: 0.10292347738199109
# The Disparate impact ratio on the training data: 0.9523355422167098
#
# ===After training the model===
# The accuracy score for the testing data: 0.6006976858448386
# The precision score for the testing data: 0.1534090909090909
# The recall score for the testing data: 0.570673712021136
# The F1 score for the testing data: 0.24181360201511334
# The F2 score for the testing data: 0.36960985626283366
# The specificity score for the testing data: 0.6044685322420086
# The balanced accuracy score for the testing data: 0.5875711221315723
# The G mean score for the testing data: 0.5873281034434797
# [[10930  7152]
#  [  975  1296]]
#                 selection_rate
# race
# AfricanAmerican       0.403599
# Caucasian             0.428891
# Other                 0.293124
# Unknown               0.263529
# The Demographic parity difference score on the trained model: 0.165361376584298
# The Equalized odds difference score on the trained model: 0.2948753271800523
# The Equal opportunity difference score on the trained model: 0.570673712021136
# The Disparate impact ratio on the trained model: 0.8725353987290814
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC3E3DC30>
#
# sensitive-resample, w/o sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.114843
# Caucasian             0.106717
# Other                 0.096425
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.0314192849404117
# The Disparate impact ratio on the training data: 0.9204737732656514
#
# ===After training the model===
# The accuracy score for the testing data: 0.8886650616616715
# The precision score for the testing data: 0.6470588235294118
# The recall score for the testing data: 0.0048436811977102595
# The F1 score for the testing data: 0.009615384615384614
# The F2 score for the testing data: 0.006043291945940005
# The specificity score for the testing data: 0.9996681782988608
# The balanced accuracy score for the testing data: 0.5022559297482855
# The G mean score for the testing data: 0.06958501246084145
# [[18076     6]
#  [ 2260    11]]
#                 selection_rate
# race
# AfricanAmerican       0.001028
# Caucasian             0.000789
# Other                 0.001206
# Unknown                    0.0
# The Demographic parity difference score on the trained model: 0.0012062726176115801
# The Equalized odds difference score on the trained model: 0.01282051282051282
# The Equal opportunity difference score on the trained model: 0.0048436811977102595
# The Disparate impact ratio on the trained model: 1.2319368843960603
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC244F9D0>
#
# sensitive-resample, with sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# race
# AfricanAmerican       0.114843
# Caucasian             0.106717
# Other                 0.096425
# Unknown               0.083424
# The Demographic parity difference score on the training data: 0.0314192849404117
# The Disparate impact ratio on the training data: 0.9204737732656514
#
# ===After training the model===
# The accuracy score for the testing data: 0.8886650616616715
# The precision score for the testing data: 0.8571428571428571
# The recall score for the testing data: 0.002642007926023778
# The F1 score for the testing data: 0.005267778753292362
# The F2 score for the testing data: 0.003299967000329997
# The specificity score for the testing data: 0.9999446963831434
# The balanced accuracy score for the testing data: 0.5012933521545836
# The G mean score for the testing data: 0.051399044868846604
# [[18081     1]
#  [ 2265     6]]
#                 selection_rate
# race
# AfricanAmerican       0.000257
# Caucasian             0.000329
# Other                 0.001206
# Unknown                    0.0
# The Demographic parity difference score on the trained model: 0.0012062726176115801
# The Equalized odds difference score on the trained model: 0.01282051282051282
# The Equal opportunity difference score on the trained model: 0.002642007926023778
# The Disparate impact ratio on the trained model: 1.1826594090202176
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC23A4E50>
#
# multivariate-resample, w/o sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican            0.5
# Caucasian                  0.5
# Other                      0.5
# Unknown                    0.5
# The Demographic parity difference score on the training data: 0.0
# The Disparate impact ratio on the training data: 1.0
#
# ===After training the model===
# The accuracy score for the testing data: 0.5495504348253328
# The precision score for the testing data: 0.13726727674345218
# The recall score for the testing data: 0.5746367239101717
# The F1 score for the testing data: 0.2215995924605196
# The F2 score for the testing data: 0.3509762788446022
# The specificity score for the testing data: 0.5463997345426391
# The balanced accuracy score for the testing data: 0.5605182292264055
# The G mean score for the testing data: 0.5603403906581871
# [[9880 8202]
#  [ 966 1305]]
#                 selection_rate
# race
# AfricanAmerican       0.469409
# Caucasian             0.472286
# Other                 0.389626
# Unknown               0.411765
# The Demographic parity difference score on the trained model: 0.08266009087216708
# The Equalized odds difference score on the trained model: 0.08882993428212793
# The Equal opportunity difference score on the trained model: 0.5746367239101717
# The Disparate impact ratio on the trained model: 0.9565990764871871
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC23C6C80>
#
# multivariate-resample, with sensitive attribute
#
# ===Before training the model===
#                 selection_rate
# 0
# AfricanAmerican            0.5
# Caucasian                  0.5
# Other                      0.5
# Unknown                    0.5
# The Demographic parity difference score on the training data: 0.0
# The Disparate impact ratio on the training data: 1.0
#
# ===After training the model===
# The accuracy score for the testing data: 0.5598191912740137
# The precision score for the testing data: 0.13825183903072263
# The recall score for the testing data: 0.5627476882430648
# The F1 score for the testing data: 0.22197134172818064
# The F2 score for the testing data: 0.34864687909209946
# The specificity score for the testing data: 0.5594513881207831
# The balanced accuracy score for the testing data: 0.5610995381819239
# The G mean score for the testing data: 0.5610971175735483
# [[10116  7966]
#  [  993  1278]]
#                 selection_rate
# race
# AfricanAmerican       0.454756
# Caucasian             0.459202
# Other                  0.37877
# Unknown               0.416471
# The Demographic parity difference score on the trained model: 0.08043218648471823
# The Equalized odds difference score on the trained model: 0.10256410256410253
# The Equal opportunity difference score on the trained model: 0.5627476882430648
# The Disparate impact ratio on the trained model: 0.9567619789467685
# c:\Users\Tanya\Desktop\TANYA\FMI\Masters\thesis\src\env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <sklearn.metrics._plot.roc_curve.RocCurveDisplay object at 0x000001AEC241D750>
